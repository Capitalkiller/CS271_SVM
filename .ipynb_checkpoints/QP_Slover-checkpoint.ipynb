# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from sklearn import svm
from lib import *
from svm import *
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
data, lable  = load_train("./data/0vs8Source.csv")
train_data, train_lable, validation_data, validation_lable = shuffleData(data, lable)
print "train data: ", train_data.shape
print "train lable: ", train_lable.shape
print "validation data: ", validation_data.shape
print "validation lable: ", validation_lable.shape
# Out:
# train data:  (432L, 16L)
# train lable:  (432L,)
# validation data:  (49L, 16L)
# validation lable:  (49L,)

# %%
train_data, train_lable =  load_train("./data/0vs8Source.csv")
print "train data: ", train_data.shape
print "train lable: ", train_lable.shape
# Out:
# train data:  (481L, 16L)
# train lable:  (481L,)

# %%
target_data, target_lable  = load_train("./data/0vs8Target.csv")
target_data, target_lable, target_v_data, target_v_lable = shuffleData(target_data, target_lable)
print "train data: ", target_data.shape
print "train lable: ", target_lable.shape
print "validation data: ", target_v_data.shape
print "validation lable: ", target_v_lable.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1551fe91cf27> in <module>()
# ----> 1 target_data, target_lable  = load_train("./data/0vs8Target.csv")
#       2 target_data, target_lable, target_v_data, target_v_lable = shuffleData(target_data, target_lable)
#       3 print "train data: ", target_data.shape
#       4 print "train lable: ", target_lable.shape
#       5 print "validation data: ", target_v_data.shape
#
# NameError: name 'load_train' is not defined

# %%
    target_data, target_lable  = load_train("./data/0vs8Target.csv")
    print "target data: ", target_data.shape
    print "target lable: ", target_lable.shape
# Out:
# train data:  (39L, 16L)
# train lable:  (39L,)

# %%
# it is 0 vs 8 problem, so divde only two class
train_lable[train_lable <= 4 ] = -1
train_lable[train_lable > 4] = 1
validation_lable[validation_lable <= 4 ] = -1
validation_lable[validation_lable > 4] = 1

# %%
target_lable[target_lable <= 4 ] = -1
target_lable[target_lable > 4] = 1
target_v_lable[target_v_lable <= 4 ] = -1
target_v_lable[target_v_lable > 4] = 1

# %%
w, b = QP_Slover(train_data, train_lable)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.146936325917
#             Iterations: 7
#             Function evaluations: 134
#             Gradient evaluations: 7

# %%
pre_vali = prediction_QP(w, b, target_data)
correct_rate_only(pre_vali, target_lable)
# Out:
# 0.8974358974358975

# %%
w_target, b_target = QP_Slover_transfer(target_data, target_lable, w, 70)
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.029366535253
#             Iterations: 29
#             Function evaluations: 567
#             Gradient evaluations: 29

# %%
pre_vali = prediction_QP(w_target, b_target, target_data)
correct_rate_only(pre_vali, target_lable)
# Out:
# 1.0

# %%
test_data  = load_test("./data/0vs8TestNoLabels.csv")
print "train data: ", test_data.shape
# Out:
# (200L, 16L)
# train data:  (200L, 16L)

# %%
pre_test = prediction_QP(w_target, b_target, test_data)
test_lable = np.zeros(200)
test_lable[:100] = 1
test_lable[100:] = -1

# %%
correct_rate_only(pre_test, test_lable)
# Out:
# 0.905

# %%
k = 0.0006000000000000001
w_target, b_target = QP_Slover_transfer(target_data, target_lable, w, k)
pre_test = prediction_QP(w_target, b_target, test_data)
pre_test[pre_test>0] = 8
pre_test[pre_test<0] = 0
np.savetxt('predect_0vs8_test.txt', pre_test,fmt='%i')
# Out:
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145528641632
#             Iterations: 101
#             Function evaluations: 2233
#             Gradient evaluations: 100

# %%
trace_k =[]
trace_rate =[]
best = 0
best_k = 0
for i in range(100):
    k = 0.00001*i
    w_target, b_target = QP_Slover_transfer(target_data, target_lable, w, k)
    pre_test = prediction_QP(w_target, b_target, test_data)
    rate = correct_rate_only(pre_test, test_lable)
    trace_rate.append(rate)
    trace_k.append(k)
    if best < rate:
        best = rate
        best_k = k
    print rate
plt.plot(trace_k, trace_rate)    
print "best rate = %r, best k = %r" %(best, best_k)
# Out:
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145041856417
#             Iterations: 101
#             Function evaluations: 2260
#             Gradient evaluations: 101
# 0.87
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146202524409
#             Iterations: 101
#             Function evaluations: 2274
#             Gradient evaluations: 101
# 0.9
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.147495792041
#             Iterations: 101
#             Function evaluations: 2352
#             Gradient evaluations: 101
# 0.935
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145185615978
#             Iterations: 101
#             Function evaluations: 2307
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145552329761
#             Iterations: 101
#             Function evaluations: 2255
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145898667456
#             Iterations: 101
#             Function evaluations: 2253
#             Gradient evaluations: 100
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145224750696
#             Iterations: 101
#             Function evaluations: 2299
#             Gradient evaluations: 100
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14400556962
#             Iterations: 101
#             Function evaluations: 2353
#             Gradient evaluations: 100
# 0.875
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14657397521
#             Iterations: 101
#             Function evaluations: 2264
#             Gradient evaluations: 101
# 0.915
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145665122789
#             Iterations: 101
#             Function evaluations: 2178
#             Gradient evaluations: 100
# 0.935
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145511075424
#             Iterations: 101
#             Function evaluations: 2335
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145388633904
#             Iterations: 101
#             Function evaluations: 2303
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145272085381
#             Iterations: 101
#             Function evaluations: 2382
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14560710137
#             Iterations: 101
#             Function evaluations: 2346
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145464159361
#             Iterations: 101
#             Function evaluations: 2363
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144331050983
#             Iterations: 101
#             Function evaluations: 2285
#             Gradient evaluations: 101
# 0.88
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146258896657
#             Iterations: 101
#             Function evaluations: 2362
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146147650861
#             Iterations: 101
#             Function evaluations: 2293
#             Gradient evaluations: 101
# 0.85
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.147529367784
#             Iterations: 101
#             Function evaluations: 2286
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145223003776
#             Iterations: 101
#             Function evaluations: 2317
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144976374901
#             Iterations: 101
#             Function evaluations: 2245
#             Gradient evaluations: 101
# 0.91
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146741218524
#             Iterations: 101
#             Function evaluations: 2254
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145612689858
#             Iterations: 101
#             Function evaluations: 2325
#             Gradient evaluations: 100
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145115149329
#             Iterations: 101
#             Function evaluations: 2354
#             Gradient evaluations: 100
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145002631898
#             Iterations: 101
#             Function evaluations: 2246
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.1459254365
#             Iterations: 101
#             Function evaluations: 2320
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144061252919
#             Iterations: 101
#             Function evaluations: 2210
#             Gradient evaluations: 101
# 0.935
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145169843667
#             Iterations: 101
#             Function evaluations: 2302
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.143966588465
#             Iterations: 101
#             Function evaluations: 2258
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145857686093
#             Iterations: 101
#             Function evaluations: 2278
#             Gradient evaluations: 101
# 0.865
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144918487097
#             Iterations: 101
#             Function evaluations: 2272
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146443137805
#             Iterations: 101
#             Function evaluations: 2300
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.147904319691
#             Iterations: 101
#             Function evaluations: 2300
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145211852991
#             Iterations: 101
#             Function evaluations: 2294
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146279311285
#             Iterations: 101
#             Function evaluations: 2243
#             Gradient evaluations: 100
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145749168771
#             Iterations: 101
#             Function evaluations: 2279
#             Gradient evaluations: 101
# 0.86
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145877281217
#             Iterations: 101
#             Function evaluations: 2321
#             Gradient evaluations: 101
# 0.915
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145382636297
#             Iterations: 101
#             Function evaluations: 2219
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144930215617
#             Iterations: 101
#             Function evaluations: 2277
#             Gradient evaluations: 100
# 0.895
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145252162814
#             Iterations: 101
#             Function evaluations: 2238
#             Gradient evaluations: 101
# 0.91
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14505376198
#             Iterations: 101
#             Function evaluations: 2292
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145482947751
#             Iterations: 101
#             Function evaluations: 2266
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145076978058
#             Iterations: 101
#             Function evaluations: 2401
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145362446738
#             Iterations: 101
#             Function evaluations: 2254
#             Gradient evaluations: 101
# 0.935
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146407223677
#             Iterations: 101
#             Function evaluations: 2308
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145219568587
#             Iterations: 101
#             Function evaluations: 2216
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146428124542
#             Iterations: 101
#             Function evaluations: 2362
#             Gradient evaluations: 101
# 0.935
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145410257318
#             Iterations: 101
#             Function evaluations: 2362
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145980410247
#             Iterations: 101
#             Function evaluations: 2277
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146362996075
#             Iterations: 101
#             Function evaluations: 2292
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.148514669805
#             Iterations: 101
#             Function evaluations: 2361
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144688146519
#             Iterations: 101
#             Function evaluations: 2334
#             Gradient evaluations: 100
# 0.89
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14489705363
#             Iterations: 101
#             Function evaluations: 2287
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14394729541
#             Iterations: 101
#             Function evaluations: 2249
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14522029546
#             Iterations: 101
#             Function evaluations: 2298
#             Gradient evaluations: 100
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145967918667
#             Iterations: 101
#             Function evaluations: 2268
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146196439668
#             Iterations: 101
#             Function evaluations: 2271
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145632087786
#             Iterations: 101
#             Function evaluations: 2267
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146610935301
#             Iterations: 101
#             Function evaluations: 2249
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146890132657
#             Iterations: 101
#             Function evaluations: 2293
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144892205511
#             Iterations: 101
#             Function evaluations: 2290
#             Gradient evaluations: 101
# 0.94
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145717245655
#             Iterations: 101
#             Function evaluations: 2349
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145095219809
#             Iterations: 101
#             Function evaluations: 2341
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145518493902
#             Iterations: 101
#             Function evaluations: 2339
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.147045129616
#             Iterations: 101
#             Function evaluations: 2265
#             Gradient evaluations: 101
# 0.9
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144287421828
#             Iterations: 101
#             Function evaluations: 2294
#             Gradient evaluations: 101
# 0.885
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146844500084
#             Iterations: 101
#             Function evaluations: 2331
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144640532535
#             Iterations: 101
#             Function evaluations: 2255
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146880910948
#             Iterations: 101
#             Function evaluations: 2320
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145526982234
#             Iterations: 101
#             Function evaluations: 2399
#             Gradient evaluations: 100
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144882733951
#             Iterations: 101
#             Function evaluations: 2314
#             Gradient evaluations: 100
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145123809955
#             Iterations: 101
#             Function evaluations: 2328
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145979804092
#             Iterations: 101
#             Function evaluations: 2234
#             Gradient evaluations: 101
# 0.935
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.147088745122
#             Iterations: 101
#             Function evaluations: 2381
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144787320463
#             Iterations: 101
#             Function evaluations: 2256
#             Gradient evaluations: 101
# 0.935
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144900655699
#             Iterations: 101
#             Function evaluations: 2339
#             Gradient evaluations: 100
# 0.885
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145223834093
#             Iterations: 101
#             Function evaluations: 2263
#             Gradient evaluations: 101
# 0.915
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145172408879
#             Iterations: 101
#             Function evaluations: 2248
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145516174552
#             Iterations: 101
#             Function evaluations: 2302
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14519385227
#             Iterations: 101
#             Function evaluations: 2281
#             Gradient evaluations: 101
# 0.915
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144883061733
#             Iterations: 101
#             Function evaluations: 2316
#             Gradient evaluations: 101
# 0.885
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.144895364379
#             Iterations: 101
#             Function evaluations: 2292
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145611319095
#             Iterations: 101
#             Function evaluations: 2319
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146246032203
#             Iterations: 101
#             Function evaluations: 2361
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146944431064
#             Iterations: 101
#             Function evaluations: 2296
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145001533459
#             Iterations: 101
#             Function evaluations: 2262
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146548079139
#             Iterations: 101
#             Function evaluations: 2357
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14620590878
#             Iterations: 101
#             Function evaluations: 2284
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146082657562
#             Iterations: 101
#             Function evaluations: 2369
#             Gradient evaluations: 101
# 0.935
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.14570529078
#             Iterations: 101
#             Function evaluations: 2351
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.146242470709
#             Iterations: 101
#             Function evaluations: 2270
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145099546282
#             Iterations: 101
#             Function evaluations: 2328
#             Gradient evaluations: 100
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145993202074
#             Iterations: 101
#             Function evaluations: 2402
#             Gradient evaluations: 100
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145620601101
#             Iterations: 101
#             Function evaluations: 2376
#             Gradient evaluations: 101
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145206185858
#             Iterations: 101
#             Function evaluations: 2265
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145421782216
#             Iterations: 101
#             Function evaluations: 2356
#             Gradient evaluations: 100
# 0.925
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145114411779
#             Iterations: 101
#             Function evaluations: 2308
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145105990496
#             Iterations: 101
#             Function evaluations: 2307
#             Gradient evaluations: 101
# 0.92
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.145928425977
#             Iterations: 101
#             Function evaluations: 2341
#             Gradient evaluations: 101
# 0.93
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 0.147427104913
#             Iterations: 101
#             Function evaluations: 2309
#             Gradient evaluations: 101
# 0.935
# best rate = 0.94, best k = 0.0006000000000000001
